# %%
import pandas as pd
import os
import ast

# %%
folder_path = r"..\csv"
print(os.listdir(folder_path))
# Out:
# ['company.csv', 'company_companies_statues.csv', 'company_developed.csv', 'company_logo.csv', 'company_logos.csv', 'company_parent_modified.csv', 'company_statues.csv', 'game.csv', 'games.csv', 'gamespot_games.csv', 'game_age_ratings.csv', 'game_all.csv', 'game_engines.csv', 'game_engines_logos.csv', 'game_game_type.csv', 'game_genre.csv', 'game_multiplayer_mode.csv', 'game_platform_multiplayer_mode.csv', 'game_player_perspective.csv', 'game_player_perspective_exploded.csv', 'game_types.csv', 'game_video.csv', 'genre_id.csv', 'jeux_video_rawg.csv', 'language.csv', 'language_supports.csv', 'language_supports_type.csv', 'multiplayer_modes.csv', 'plaform_platform_version.csv', 'plaform_version.csv', 'player_perspectives.csv']

# %%
# Import de la table
games = pd.read_csv(r'..\csv\games.csv')
language_supports = pd.read_csv(r'..\csv\language_supports.csv')
language = pd.read_csv(r'..\csv\language.csv')
language_supports_type = pd.read_csv(r'..\csv\language_supports_type.csv')
game_genre = pd.read_csv(r'..\csv\game_genre.csv')
genre_id = pd.read_csv(r'..\csv\genre_id.csv')
game_game_type = pd.read_csv(r'..\csv\game_game_type.csv')
game_types = pd.read_csv(r'..\csv\game_types.csv')
players = pd.read_csv(r'..\csv\game_player_perspective_exploded.csv')
playeur_persp = pd.read_csv(r'..\csv\player_perspectives.csv')

# %%
# --------  Games --------
# Supprimer les doublons
games = games.drop_duplicates()
# Drop de la colonne avec trop de missing
games.drop('total_rating', axis=1, inplace=True)
games
# Out:
#             id                                           name  \
# 0       330684                  Nightmare Kart: The Old Karts
# 1       177310                              The Undying Beast
# 2       129194                    Arcade Archives: XX Mission
# 3       282079                       Rockman X: New Year 2023
# 4        63844                                  Ace wo Nerae!
# ...        ...                                            ...
# 323485   89219  Stronghold Crusader II: The Templar &The Duke
# 323486    8993                              Anomaly Defenders
# 323487  154420                                 Catacombs Pack
# 323488    6253                        Time Gentlemen, Please!
# 323489   11261                               The Black Mirror
#
#                                                      slug  \
# 0                            nightmare-kart-the-old-karts
# 1                                       the-undying-beast
# 2                              arcade-archives-xx-mission
# 3                                 rockman-x-new-year-2023
# 4                                            ace-wo-nerae
# ...                                                   ...
# 323485  stronghold-crusader-ii-the-templar-and-the-duk...
# 323486                                  anomaly-defenders
# 323487                                     catacombs-pack
# 323488                              time-gentlemen-please
# 323489                                   the-black-mirror
#
#                                                   summary first_release_date
# 0       An upcoming free expansion to Nightmare Kart w...                NaN
# 1       There was a flash of light, a choir of glass, ...         2020-04-13
# 2       XX Mission is a shooting game released by UPL ...         2020-01-23
# 3       A small hack to celebrate the Chinese New Year...         2023-01-01
# 4       A tennis game for the Super Famicom based on t...         1993-12-22
# ...                                                   ...                ...
# 323485  The law of the Templar is coming to the desert...         2015-07-01
# 323486  Anomaly Defenders is the closing installment o...         2014-05-29
# 323487  Catacombs Pack is a fantastic compilation of t...         2013-03-14
# 323488  Ben There, Dan That! and Time Gentlemen, Pleas...         2009-06-22
# 323489  Black Mirror is a dark adventure game that det...         2003-10-17
#
# [323482 rows x 5 columns]

# %%
# --------  game_genre --------
# Transformer les chaines en listes pour explode après
game_genre['genres'] = game_genre['genres'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else [])
game_genre = game_genre.explode('genres')
game_genre['genres'] = game_genre['genres'].astype(float)
# renommer id en game_id 
game_genre = game_genre.rename({'id': 'game_id', 'genres': 'genres_id'}, axis=1)
game_genre
# Out:
#         game_id  genres_id
# 0        330684       10.0
# 0        330684       33.0
# 1        177310       13.0
# 1        177310       32.0
# 2        129194        5.0
# ...         ...        ...
# 323475     6253        9.0
# 323475     6253       31.0
# 323475     6253       32.0
# 323476    11261        2.0
# 323476    11261       31.0
#
# [573856 rows x 2 columns]

# %%
# -------------------------------
game_languages = pd.merge(language_supports, language, how='left', left_on='language', right_on='id')
game_langue = pd.merge(game_languages, language_supports_type, how='left', left_on='language_support_type', right_on='id')
# renommer colonne id_x et id_y
game_langue.rename(columns={'id' : 'language_type_id', 'id_x': 'language_support_id', 'id_y': 'language_id'}, inplace=True)
game_langue
# Out:
#          language_support_id    game  language  language_support_type  \
# 0                       1001  113494         7                      1
# 1                    1042224  309457        13                      1
# 2                       4001   76477         7                      2
# 3                       2001   24816         1                      3
# 4                       6001  112929        22                      3
# ...                      ...     ...       ...                    ...
# 1234277              1307197  353901        27                      3
# 1234278              1307209  353901        17                      2
# 1234279              1307195  353901        12                      3
# 1234280              1307207  353901         9                      2
# 1234281              1307206  353901        27                      2
#
#          language_id           name_x       native_name locale  \
# 0                  7          English      English (US)  en-US
# 1                 13           Hebrew             עברית  he-IL
# 2                  7          English      English (US)  en-US
# 3                  1           Arabic           العربية     ar
# 4                 22          Russian           Русский  ru-RU
# ...              ...              ...               ...    ...
# 1234277           27           German           Deutsch  de-DE
# 1234278           17           Korean               한국어  ko-KR
# 1234279           12           French          Français  fr-FR
# 1234280            9  Spanish (Spain)  Español (España)  es-ES
# 1234281           27           German           Deutsch  de-DE
#
#          language_type_id     name_y
# 0                       1      Audio
# 1                       1      Audio
# 2                       2  Subtitles
# 3                       3  Interface
# 4                       3  Interface
# ...                   ...        ...
# 1234277                 3  Interface
# 1234278                 2  Subtitles
# 1234279                 3  Interface
# 1234280                 2  Subtitles
# 1234281                 2  Subtitles
#
# [1234282 rows x 10 columns]

# %%
jeux = pd.merge(games, game_langue, how='left', right_on='game', left_on ='id')

jeux = jeux.drop(columns = ['language_support_id','language', 'language_id', 'language_support_type',
                            'native_name', 'locale', 'language_type_id','game'])
# renommer colonne
jeux = jeux.rename(columns = {'name_x':'langue', 'name_y': 'support_type'})
jeux
# Out:
#              id                           name                          slug  \
# 0        330684  Nightmare Kart: The Old Karts  nightmare-kart-the-old-karts
# 1        177310              The Undying Beast             the-undying-beast
# 2        129194    Arcade Archives: XX Mission    arcade-archives-xx-mission
# 3        129194    Arcade Archives: XX Mission    arcade-archives-xx-mission
# 4        129194    Arcade Archives: XX Mission    arcade-archives-xx-mission
# ...         ...                            ...                           ...
# 1375861   11261               The Black Mirror              the-black-mirror
# 1375862   11261               The Black Mirror              the-black-mirror
# 1375863   11261               The Black Mirror              the-black-mirror
# 1375864   11261               The Black Mirror              the-black-mirror
# 1375865   11261               The Black Mirror              the-black-mirror
#
#                                                    summary first_release_date  \
# 0        An upcoming free expansion to Nightmare Kart w...                NaN
# 1        There was a flash of light, a choir of glass, ...         2020-04-13
# 2        XX Mission is a shooting game released by UPL ...         2020-01-23
# 3        XX Mission is a shooting game released by UPL ...         2020-01-23
# 4        XX Mission is a shooting game released by UPL ...         2020-01-23
# ...                                                    ...                ...
# 1375861  Black Mirror is a dark adventure game that det...         2003-10-17
# 1375862  Black Mirror is a dark adventure game that det...         2003-10-17
# 1375863  Black Mirror is a dark adventure game that det...         2003-10-17
# 1375864  Black Mirror is a dark adventure game that det...         2003-10-17
# 1375865  Black Mirror is a dark adventure game that det...         2003-10-17
#
#                   langue support_type
# 0                    NaN          NaN
# 1                    NaN          NaN
# 2                English    Interface
# 3                 French    Interface
# 4                Italian    Interface
# ...                  ...          ...
# 1375861           French    Subtitles
# 1375862          English    Subtitles
# 1375863  Spanish (Spain)    Subtitles
# 1375864           Polish    Subtitles
# 1375865          Russian    Subtitles
#
# [1375866 rows x 7 columns]

# %%
# -
genres = pd.merge(game_genre, genre_id, how='left', left_on='genres_id', right_on='id')
genres.drop('id', axis = 1, inplace=True)
genres
# Out:
#         game_id  genres_id             name
# 0        330684       10.0           Racing
# 1        330684       33.0           Arcade
# 2        177310       13.0        Simulator
# 3        177310       32.0            Indie
# 4        129194        5.0          Shooter
# ...         ...        ...              ...
# 573851     6253        9.0           Puzzle
# 573852     6253       31.0        Adventure
# 573853     6253       32.0            Indie
# 573854    11261        2.0  Point-and-click
# 573855    11261       31.0        Adventure
#
# [573856 rows x 3 columns]

# %%
# --
jeu = pd.merge(jeux,genres, how = 'left', left_on = 'id', right_on = 'game_id')
jeu = jeu.drop('game_id', axis = 1)

# %%
jeud = jeu.groupby('id').agg({'langue': lambda x: list(set(x)) if x.dropna().size > 0 else [], 
                                'support_type': lambda x: list(set(x)) if x.dropna().size > 0 else [], 
                                'name_x': 'first',
                                'slug':'first',
                                'summary': 'first',
                                'first_release_date':'first',
                                'genres_id': lambda x: list(set(x)) if x.dropna().size > 0 else [], 
                                'name_y': lambda x: list(set(x)) if x.dropna().size > 0 else []
                                }).reset_index()
# Out:
#             id                                             langue  \
# 0            1                                  [French, English]
# 1            2                                                 []
# 2            3                 [French, Italian, German, English]
# 3            4  [French, Italian, Czech, German, English, Span...
# 4            5                                                 []
# ...        ...                                                ...
# 323477  353895                                          [English]
# 323478  353896                                                 []
# 323479  353897                                                 []
# 323480  353898                                  [French, English]
# 323481  353901  [French, Italian, Korean, Chinese (Simplified)...
#
#                          support_type                   name_x  \
# 0                  [Interface, Audio]  Thief II: The Metal Age
# 1                                  []  Thief: The Dark Project
# 2                  [Interface, Audio]    Thief: Deadly Shadows
# 3       [Interface, Subtitles, Audio]                    Thief
# 4                                  []            Baldur's Gate
# ...                               ...                      ...
# 323477         [Interface, Subtitles]                Fish Face
# 323478                             []      Cavalry Battle 3000
# 323479                             []                  Steamle
# 323480  [Interface, Subtitles, Audio]           Nelli the Seer
# 323481  [Interface, Subtitles, Audio]                 NBA 2K26
#
#                           slug  \
# 0       thief-ii-the-metal-age
# 1       thief-the-dark-project
# 2         thief-deadly-shadows
# 3                        thief
# 4                baldur-s-gate
# ...                        ...
# 323477            fish-face--1
# 323478     cavalry-battle-3000
# 323479                 steamle
# 323480          nelli-the-seer
# 323481                nba-2k26
#
#                                                   summary first_release_date  \
# 0       The ultimate thief is back! Tread softly as yo...         2000-03-21
# 1       Thief is a first-person stealth game that like...         1998-11-30
# 2       In the third instalment of the Thief series, m...         2004-05-25
# 3       There is a rising tide of fear in The City. Ha...         2014-02-25
# 4       Baldur's Gate is a fantasy role-playing video ...         1998-12-21
# ...                                                   ...                ...
# 323477  Search for a new face in a unnervingly peacefu...         2025-06-29
# 323478                                               None               None
# 323479  Steamle is a daily guessing game where you try...         2025-07-04
# 323480  Nelli The Seer is a third-person platformer an...         2025-07-09
# 323481  Bragging rights are on the line in MyCAREER, M...         2025-09-05
#
#                 genres_id                           name_y
# 0       [13.0, 5.0, 31.0]  [Shooter, Simulator, Adventure]
# 1            [13.0, 31.0]           [Simulator, Adventure]
# 2       [13.0, 5.0, 31.0]  [Shooter, Simulator, Adventure]
# 3             [5.0, 31.0]             [Shooter, Adventure]
# 4                  [12.0]             [Role-playing (RPG)]
# ...                   ...                              ...
# 323477       [34.0, 13.0]        [Simulator, Visual Novel]
# 323478                 []                               []
# 323479             [26.0]                    [Quiz/Trivia]
# 323480             [31.0]                      [Adventure]
# 323481             [14.0]                          [Sport]
#
# [323482 rows x 9 columns]

# %%
jeud = jeud.rename(columns={'name_x':'name', 'name_y':'genres'})

# %%
game_type = pd.merge(game_game_type, game_types, how='left', left_on='game_type', right_on='id')
game_type.drop(columns=['game_type', 'id_y'], inplace=True)

# %%
jeu_game = pd.merge(jeud, game_type, how='left', left_on='id', right_on='id_x')
jeu_game.drop(columns = ['id_x'], inplace=True)

# %%
player = pd.merge(players, playeur_persp, how='left', left_on='player_perspectives', right_on='id')
player.drop(columns=['player_perspectives', 'id','slug'], inplace=True)
player = player.groupby('game_id').agg({'name': lambda x: list(set(x)) if x.dropna().size > 0 else []}).reset_index()

# %%
game_all = pd.merge(jeu_game, player, how='left', left_on='id', right_on='game_id')
game_all.drop('game_id', axis = 1, inplace=True)
game_all = game_all.rename(columns={'name_x':'game_name', 'name_y':'players_perspectives'})

# %%
# suppression de la ligne vide car pas de nom
game_all = game_all[game_all['game_name'].notna()]
game_all['type'] = game_all['type'].fillna('unknown')
game_all['type'] = game_all['type'].apply(lambda x: [x])
game_all['players_perspectives'] = game_all['players_perspectives'].apply(lambda x: x if isinstance(x, list) else [])
# cjnger format des colonnes de game_all
game_all['first_release_date'] = pd.to_datetime(game_all['first_release_date'], errors='coerce')
game_all['year'] = game_all['first_release_date'].dt.year
def year_to_period(year):
    if pd.isna(year):
        return 'Unknown'
    elif year < 2000:
        return 'Before 2000'
    elif year < 2010:
        return '2000s'
    elif year < 2020:
        return '2010s'
    else:
        return '2020s'

game_all['release_period'] = game_all['year'].apply(year_to_period)
 # Pour compatibilité avec MultiLabelBinarizer
game_all['release_period'] = game_all['release_period'].apply(lambda x: [x])

# %%
from sklearn.preprocessing import MultiLabelBinarizer
import pandas as pd

# Liste des colonnes à inclure dans la recommandation
list_columns = ['genres', 'players_perspectives', 'release_period', 'type']
encoded_features = []

# Encodage binaire de chaque colonne
for col in list_columns:
    mlb = MultiLabelBinarizer()
    encoded = mlb.fit_transform(game_all[col])
    encoded_df = pd.DataFrame(encoded, columns=[f"{col}_{cls}" for cls in mlb.classes_])
    encoded_features.append(encoded_df)

# Fusion de tous les encodages
features_matrix = pd.concat(encoded_features, axis=1)
features_matrix.index = game_all['game_name']

# %%
from sklearn.neighbors import NearestNeighbors

# Modèle KNN
knn_model = NearestNeighbors(metric='cosine', algorithm='brute')
knn_model.fit(features_matrix)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine')

# %%
def recommend_games(game_name, n=5):
    if game_name not in features_matrix.index:
        print(f"Le jeu '{game_name}' n'est pas dans le dataset.")
        return []
    
    game_vector = features_matrix.loc[game_name].values.reshape(1, -1)
    distances, indices = knn_model.kneighbors(game_vector, n_neighbors=n+1)
    
    # Indice 0 est le jeu lui-même → on l'exclut
    recommended_indices = indices.flatten()[1:]
    recommended_games = features_matrix.index[recommended_indices]
    
    print(f" Recommandations similaires à '{game_name}' :\n")
    for i, name in enumerate(recommended_games, 1):
        print(f"{i}. {name}")
    
    return recommended_games.tolist()

# %%
recommend_games("Baldur's Gate", n=5)
# Out:
# c:\Users\sirnb\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
#  Recommandations similaires à 'Baldur's Gate' :
#
# 1. The Kingdom of Syree II: Black Magic
# 2. Outlanders
# 3. Onyanko Town
# 4. Sansara Naga
# 5. Elemental Force
# ['The Kingdom of Syree II: Black Magic',
#  'Outlanders',
#  'Onyanko Town',
#  'Sansara Naga',
#  'Elemental Force']
